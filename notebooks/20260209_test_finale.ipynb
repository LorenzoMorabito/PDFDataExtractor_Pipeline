# %%
# %pip install -r ../requirements.txt
# %pip install -e ../../PDFDataExtractor-lib

# %%
import json
from pathlib import Path
import sys

project_root = Path.cwd().parent  # se il notebook è in /notebooks
sys.path.insert(0, str(project_root / "src"))
from pipeline.orchestrator import run_pipeline


project_root = Path.cwd().parent  # se il notebook è in /notebooks
config_path = project_root / "configs" / "pipeline" / "pipeline_config_DEC.json"
config["extraction_config_path"] = str(project_root / "configs" / "extraction" / "extract_config_page_ALL_DEC.json")
result = run_pipeline(config)


result = run_pipeline(config)

result["df_final"].head()

# %%
result["df_final"]
